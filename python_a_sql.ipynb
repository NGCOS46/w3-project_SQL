# %%
## 1. CONEXION A MYSQL:

# %%
from sqlalchemy import create_engine
import pandas as pd 
import numpy as np

# %%
str_conn = 'mysql+pymysql://root:new_password@localhost:3306/blockbuster'

cursor = create_engine(str_conn)

# %%
## 1. DATAFRAME A UTILIZAR A MYSQL:

# %%
data = pd.read_csv(r'C:\Users\VANT\ironhack\ejercicios\w3-project_SQL\real_csv\cleaned_actor.csv')

data.head()
# Out:
#    actor_id   last_date last_hour           actor_name
# 0         1  2006-02-15  04:34:33     PENELOPE GUINESS
# 1         2  2006-02-15  04:34:33        NICK WAHLBERG
# 2         3  2006-02-15  04:34:33             ED CHASE
# 3         4  2006-02-15  04:34:33       JENNIFER DAVIS
# 4         5  2006-02-15  04:34:33  JOHNNY LOLLOBRIGIDA

# %%
cateory=pd.read_csv(r'C:\Users\VANT\ironhack\ejercicios\w3-project_SQL\real_csv\cleaned_category.csv')

cateory.head()
# Out:
#    category_id       name   last_date last_hour
# 0            1     Action  2006-02-15  04:46:27
# 1            2  Animation  2006-02-15  04:46:27
# 2            3   Children  2006-02-15  04:46:27
# 3            4   Classics  2006-02-15  04:46:27
# 4            5     Comedy  2006-02-15  04:46:27

# %%
film=pd.read_csv(r'C:\Users\VANT\ironhack\ejercicios\w3-project_SQL\real_csv\film_actor.csv')

film.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                     1                6         0.99      86
# 1            2                     2                3         4.99      48
# 2            3                     3                7         2.99      50
# 3            4                     4                5         2.99     117
# ...

# %%
inventory=pd.read_csv(r'C:\Users\VANT\ironhack\ejercicios\w3-project_SQL\real_csv\inventory_clean.csv')
inventory.head()
# Out:
#    inventory_id  film_id   last_date last_hour
# 0             1        1  2006-02-15  05:09:17
# 1             2        1  2006-02-15  05:09:17
# 2             3        1  2006-02-15  05:09:17
# 3             4        1  2006-02-15  05:09:17
# 4             5        1  2006-02-15  05:09:17

# %%
language=pd.read_csv(r'C:\Users\VANT\ironhack\ejercicios\w3-project_SQL\real_csv\language_clean.csv')
language.head()
# Out:
#    language_id      name   last_date last_hour
# 0            1   English  2006-02-15  05:02:19
# 1            2   Italian  2006-02-15  05:02:19
# 2            3  Japanese  2006-02-15  05:02:19
# 3            4  Mandarin  2006-02-15  05:02:19
# 4            5    French  2006-02-15  05:02:19

# %%
old_hdd=pd.read_csv(r'C:\Users\VANT\ironhack\ejercicios\w3-project_SQL\real_csv\old_HDD_clean.csv')
old_hdd.head()
# Out:
#                    title  release_year  category_id        actor_name
# 0       ACADEMY DINOSAUR          2006            6  PENELOPE GUINESS
# 1   ANACONDA CONFESSIONS          2006            2  PENELOPE GUINESS
# 2            ANGELS LIFE          2006           13  PENELOPE GUINESS
# 3  BULWORTH COMMANDMENTS          2006           10  PENELOPE GUINESS
# 4          CHEAPER CLYDE          2006           14  PENELOPE GUINESS

# %%
rental=pd.read_csv(r'C:\Users\VANT\ironhack\ejercicios\w3-project_SQL\real_csv\rental.csv')
rental.head()
# Out:
#    rental_id rental_date  inventory_id  customer_id return_date  staff_id  \
# 0          1  2005-05-24           367          130  2005-05-26         1
# 1          2  2005-05-24          1525          459  2005-05-28         1
# 2          3  2005-05-24          1711          408  2005-06-01         1
# 3          4  2005-05-24          2452          333  2005-06-03         2
# 4          5  2005-05-24          2079          222  2005-06-02         1
#
#   last_update
# 0  2005-05-24
# 1  2005-05-24
# 2  2005-05-24
# 3  2005-05-24
# 4  2005-05-24

# %%
## 1. INSERCIONES DENTRO DE MYSQL:

# %%
table_name = 'actor'
data.to_sql(name=table_name, con=cursor, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1932, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1931     if not evt_handled:
# -> 1932         self.dialect.do_executemany(
#    1933             cursor,
#    1934             str_statement,
#    1935             effective_parameters,
#    1936             context,
#    1937         )
#    1938 elif not effective_parameters and context.no_parameters:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:175, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     174 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 175     rowcount = cursor.executemany(statement, parameters)
# ...

# %%
table_name = 'cateory'
cateory.to_sql(name=table_name, con=cursor, if_exists='append', index=False)

# %%
table_name='film'
film.to_sql(name=table_name, con=cursor, if_exists='append',index=False)
# Out:
# 1000

# %%
table_name='inventory'
inventory.to_sql(name=table_name, con=cursor, if_exists='append', index=False)
# Out:
# 1000

# %%
table_name='language'
language.to_sql(name=table_name, con=cursor, if_exists='append',index=False)
# Out:
# 6

# %%
table_name='old_hdd'
old_hdd.to_sql(name=table_name, con=cursor, if_exists='append',index=False)
# Out:
# 1000

# %%
table_name='rental'
rental.to_sql(name=table_name, con=cursor, if_exists='append',index=False)
# Out:
# 1000
