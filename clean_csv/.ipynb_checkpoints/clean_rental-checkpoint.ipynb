# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\VANT\ironhack\ejercicios\w3-project_SQL\data\rental.csv')

data
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
data['rental_date'] = pd.to_datetime(data['rental_date'])
data['rental_date'] = data['rental_date'].dt.date

data['return_date'] = pd.to_datetime(data['return_date'])
data['return_date'] = data['return_date'].dt.date

data['last_update'] = pd.to_datetime(data['last_update'])
data['last_update'] = data['last_update'].dt.date

# %%
data
# Out:
#      rental_id rental_date  inventory_id  customer_id return_date  staff_id  \
# 0            1  2005-05-24           367          130  2005-05-26         1
# 1            2  2005-05-24          1525          459  2005-05-28         1
# 2            3  2005-05-24          1711          408  2005-06-01         1
# 3            4  2005-05-24          2452          333  2005-06-03         2
# 4            5  2005-05-24          2079          222  2005-06-02         1
# ..         ...         ...           ...          ...         ...       ...
# 995        997  2005-05-31          4243          216  2005-06-02         2
# 996        998  2005-05-31          3395          389  2005-06-01         1
# 997        999  2005-05-31          4433          413  2005-06-03         2
# 998       1000  2005-05-31          1774          332  2005-06-08         2
# 999       1001  2005-05-31          1498           64  2005-06-06         2
#
#     last_update
# 0    2005-05-24
# 1    2005-05-24
# ...

# %%
data.to_csv(r'C:\Users\VANT\ironhack\ejercicios\w3-project_SQL\rental.csv', index=False)
